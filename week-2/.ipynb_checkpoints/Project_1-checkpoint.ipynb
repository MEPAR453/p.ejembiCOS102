# %% [markdown]
# INPUT selected items.
# COMPUTE to find total amount or price of each selected items.
# INPUT card for payment.
# PRINT receipt after payment.
#
# ![Store checkout process.drawio.png](attachment:3b2d0bdf-6cbd-4a18-aa64-19c50beab70f.png)

# %% [markdown]
# ![morning routine.drawio.png](attachment:c8c747a5-f12d-4b77-9321-6c9a746a543c.png)

# %% [markdown]
# ![Swapping ages of input.drawio.png](attachment:b3209f55-cda5-41b4-aed4-d0925df4a75b.png)
