# %% [markdown]
# INPUT data of both boys and girls into a nested list.
# PRINT headings for each row in the data list using formatted string literal.
# PRINT data into a table using formatted string literal (f-string).

# %%
import pandas as pd

Data = [ 
    ['Abiola', 20, 5.9, 66, 'male'],
    ['Aisha', 19, 5.7, 50, 'female'],
    ['Chinedu', 19, 5.7, 74, 'male'],
    ['Edith', 18, 5.9, 60, 'female'],
    ['Evenlyn', 17, 5.5, 80, 'female'],
    ['Gbenga', 17, 6.1, 68, 'male'],
    ['George', 18, 5.4, 98, 'male'],
    ['Jessica', 16, 6.0, 85, 'female'],
    ['Kola', 19, 5.5, 78, 'male'],
    ['Kunle', 16, 6.1, 87, 'male'],
    ['Latifa', 17, 5.5, 49, 'female'],
    ['Liam', 16, 5.9, 87, 'male'],
    ['Liza', 16, 5.6, 76, 'female'],
    ['Madonna', 18, 5.5, 66, 'female'],
    ['Somto', 17, 5.4, 70, 'female'],
    ['Thomas', 17,5.8, 54, 'male'],
    ['Tola', 20, 6.0, 95, 'female'],
    ['Wale', 18, 5.8, 75, 'male'],
    ['Waje', 17, 6.1, 87, 'female'],
    ['Welsey', 19, 5.7, 60, 'male'],
]

columns = ['Name', 'Age','Height','Score','Gender']

df = pd.DataFrame(Data, columns=columns)

df
# Out:
#        Name  Age  Height  Score  Gender
# 0    Abiola   20     5.9     66    male
# 1     Aisha   19     5.7     50  female
# 2   Chinedu   19     5.7     74    male
# 3     Edith   18     5.9     60  female
# 4   Evenlyn   17     5.5     80  female
# 5    Gbenga   17     6.1     68    male
# 6    George   18     5.4     98    male
# 7   Jessica   16     6.0     85  female
# 8      Kola   19     5.5     78    male
# 9     Kunle   16     6.1     87    male
# 10   Latifa   17     5.5     49  female
# 11     Liam   16     5.9     87    male
# 12     Liza   16     5.6     76  female
# 13  Madonna   18     5.5     66  female
# 14    Somto   17     5.4     70  female
# 15   Thomas   17     5.8     54    male
# 16     Tola   20     6.0     95  female
# 17     Wale   18     5.8     75    male
# 18     Waje   17     6.1     87  female
# 19   Welsey   19     5.7     60    male
