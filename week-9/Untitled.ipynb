# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read.csv("C:\Users\New\Documents\Books\2nd Semester\COS102\Week-12\insurance.csv")
